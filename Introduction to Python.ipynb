# %% [markdown]
# # Learning Python
#
# Start with the first line of code **"Hello World"**

# %%
print("Hello World !!")
# Out:
# Hello World !!

# %% [markdown]
# Declare a variable and Initialize it !!

# %%
f = 0
print (f)
# Out:
# 0

# %% [markdown]
# Re-declaring the same variable works

# %%
f = "abc"
print (f)
# Out:
# abc

# %%
print(type(f))
# Out:
# <class 'str'>

# %% [markdown]
# **ERROR:** variables of different types cannot be combined

# %%
print ("string type " + 123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9d6e3a82b334> in <module>()
# ----> 1 print ("string type " + 123)
#
# TypeError: must be str, not int

# %%
print ("string type " + str(123))
# Out:
# string type 123

# %%
x = 'Sitaram'

# %%
y = 2

# %%
x = 10

# %%
z = x+y

# %%
print("Value of Z", z)
# Out:
# Value of Z 12

# %%
print(f"Value of Z is {z} and z plus one is {z+1}")
# Out:
# Value of Z is 12 and z plus one is 13

# %%
print(type(z))

print("value of Z is: " + str(z))  # Type casting variable z to string

print(type(str(z)))
# Out:
# <class 'float'>
# value of Z is: 10.25
# <class 'str'>

# %%
print(type(z))
# Out:
# <class 'float'>

# %%
print(type(str(z)))
# Out:
# <class 'str'>

# %%
abc = str(z)

# %%
print(type(abc))
# Out:
# <class 'str'>

# %%
print("Value of Z: ", z)
# Out:
# Value of Z:  10.25
